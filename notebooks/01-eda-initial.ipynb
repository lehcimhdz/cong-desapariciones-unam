# %% [markdown]
# # Análisis Exploratorio Inicial - Delitos CDMX
# Este notebook inicia la exploración de los datos de víctimas en carpetas de investigación utilizando el pipeline modular.

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

from src.api.client import CDMXApiClient
import matplotlib.pyplot as plt
import seaborn as sns

# %%
client = CDMXApiClient()
df = client.fetch_data_sql(limit=1000)
df.head()
